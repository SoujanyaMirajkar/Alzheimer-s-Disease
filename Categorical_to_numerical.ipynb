# %% [markdown]
# <a href="https://colab.research.google.com/github/SoujanyaMirajkar/Alzheimer-s-Disease/blob/main/Categorical_to_numerical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from mpl_toolkits.mplot3d import Axes3D
df= pd.read_csv('Alzheimer_Disease.csv')
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14056\1605791162.py:7: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('Alzheimer_Disease.csv')
#           RowId  YearStart  YearEnd LocationAbbr  \
# 0            A1       2021     2021         WEST
# 1            A2       2017     2017          NRE
# 2            A3       2019     2019          MDW
# 3            A4       2020     2020           US
# 4            A5       2020     2020           NH
# ...         ...        ...      ...          ...
# 250932  A250933       2015     2015           WV
# 250933  A250934       2015     2015           OK
# 250934  A250935       2017     2017           NH
# 250935  A250936       2015     2015           VA
# 250936  A250937       2015     2015           UT
#
#                            LocationDesc                                Class  \
# 0                                  West                       Overall Health
# 1                             Northeast                       Overall Health
# 2                               Midwest  Nutrition/Physical Activity/Obesity
# 3       United States, DC & Territories                       Overall Health
# 4                         New Hampshire                        Mental Health
# ...                                 ...                                  ...
# 250932                    West Virginia                    Cognitive Decline
# 250933                         Oklahoma                       Overall Health
# 250934                    New Hampshire                       Overall Health
# 250935                         Virginia                           Caregiving
# 250936                             Utah  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  \
# 0       Percentage of older adults ever told they have...
# 1       Percentage of older adults ever told they have...
# 2       Percentage of older adults who are eating 3 or...
# 3       Percentage of older adults ever told they have...
# 4       Percentage of older adults who are experiencin...
# ...                                                   ...
# 250932  Percentage of older adults who reported subjec...
# 250933  Mean number of days with activity limitations ...
# 250934  Severe joint pain due to arthritis among older...
# 250935  Average of 20 or more hours of care per week p...
# 250936  Percentage of older adults who are eating 3 or...
#
#        Low_Confidence_Limit High_Confidence_Limit Data_Value_Type  Data_Value  \
# 0                      28.8                  34.4      Percentage        31.6
# 1                      49.1                  51.6      Percentage        50.3
# 2                      13.8                  14.8      Percentage        14.3
# 3                      54.5                  56.4      Percentage        55.5
# 4                      12.8                    18      Percentage        15.2
# ...                     ...                   ...             ...         ...
# 250932                  NaN                   NaN      Percentage         NaN
# 250933                  4.7                   9.6            Mean         7.1
# 250934                 19.5                  24.5      Percentage        21.9
# 250935                  NaN                   NaN      Percentage         NaN
# 250936                 20.1                  39.6      Percentage        28.9
#
#                       Age  Gender               Ethnicity  \
# 0                     NaN     NaN                Hispanic
# 1       65 years or older     NaN                     NaN
# 2                     NaN     NaN                     NaN
# 3       65 years or older  Female                     NaN
# 4             50-64 years  Female                     NaN
# ...                   ...     ...                     ...
# 250932                NaN     NaN  Asian/Pacific Islander
# 250933        50-64 years     NaN     Black, non-Hispanic
# 250934                NaN     NaN                     NaN
# 250935  65 years or older     NaN                Hispanic
# 250936        50-64 years     NaN                Hispanic
#
#                                            Geolocation
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4         POINT (-71.50036091999965 43.65595011300047)
# ...                                                ...
# 250932    POINT (-80.71264013499967 38.66551020200046)
# 250933    POINT (-97.52107021399968 35.47203135600046)
# 250934    POINT (-71.50036091999965 43.65595011300047)
# 250935    POINT (-78.45789046299967 37.54268067400045)
# 250936  POINT (-111.58713063499971 39.360700171000474)
#
# [250937 rows x 16 columns]

# %% [markdown]
# Age
# 0 - 50-64
# 1 - 65 or higher

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Example dataframe with NaN values

# Creating label encoder
label_encoder = LabelEncoder()

# Handling NaN: temporarily fill NaN with a placeholder
placeholder = 'Missing'  # This should be a value not present in the data
df['Age'].fillna(placeholder, inplace=True)

# Fitting the encoder to the data (including the placeholder for NaN)
df['Age'] = label_encoder.fit_transform(df['Age'])

# Replace placeholder index back to NaN in the encoded data
placeholder_index = label_encoder.transform([placeholder])[0]
df['Age'] = df['Age'].replace(placeholder_index, pd.NA)

# Restoring NaN in the original column if desired
df['Age'].replace(placeholder, pd.NA, inplace=True)

# Output the original and encoded data
df
# Out:
#           RowId  YearStart  YearEnd LocationAbbr  \
# 0            A1       2021     2021         WEST
# 1            A2       2017     2017          NRE
# 2            A3       2019     2019          MDW
# 3            A4       2020     2020           US
# 4            A5       2020     2020           NH
# ...         ...        ...      ...          ...
# 250932  A250933       2015     2015           WV
# 250933  A250934       2015     2015           OK
# 250934  A250935       2017     2017           NH
# 250935  A250936       2015     2015           VA
# 250936  A250937       2015     2015           UT
#
#                            LocationDesc                                Class  \
# 0                                  West                       Overall Health
# 1                             Northeast                       Overall Health
# 2                               Midwest  Nutrition/Physical Activity/Obesity
# 3       United States, DC & Territories                       Overall Health
# 4                         New Hampshire                        Mental Health
# ...                                 ...                                  ...
# 250932                    West Virginia                    Cognitive Decline
# 250933                         Oklahoma                       Overall Health
# 250934                    New Hampshire                       Overall Health
# 250935                         Virginia                           Caregiving
# 250936                             Utah  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  \
# 0       Percentage of older adults ever told they have...
# 1       Percentage of older adults ever told they have...
# 2       Percentage of older adults who are eating 3 or...
# 3       Percentage of older adults ever told they have...
# 4       Percentage of older adults who are experiencin...
# ...                                                   ...
# 250932  Percentage of older adults who reported subjec...
# 250933  Mean number of days with activity limitations ...
# 250934  Severe joint pain due to arthritis among older...
# 250935  Average of 20 or more hours of care per week p...
# 250936  Percentage of older adults who are eating 3 or...
#
#        Low_Confidence_Limit High_Confidence_Limit Data_Value_Type  Data_Value  \
# 0                      28.8                  34.4      Percentage        31.6
# 1                      49.1                  51.6      Percentage        50.3
# 2                      13.8                  14.8      Percentage        14.3
# 3                      54.5                  56.4      Percentage        55.5
# 4                      12.8                    18      Percentage        15.2
# ...                     ...                   ...             ...         ...
# 250932                  NaN                   NaN      Percentage         NaN
# 250933                  4.7                   9.6            Mean         7.1
# 250934                 19.5                  24.5      Percentage        21.9
# 250935                  NaN                   NaN      Percentage         NaN
# 250936                 20.1                  39.6      Percentage        28.9
#
#          Age  Gender               Ethnicity  \
# 0       <NA>     NaN                Hispanic
# 1          1     NaN                     NaN
# 2       <NA>     NaN                     NaN
# 3          1  Female                     NaN
# 4          0  Female                     NaN
# ...      ...     ...                     ...
# 250932  <NA>     NaN  Asian/Pacific Islander
# 250933     0     NaN     Black, non-Hispanic
# 250934  <NA>     NaN                     NaN
# 250935     1     NaN                Hispanic
# 250936     0     NaN                Hispanic
#
#                                            Geolocation
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4         POINT (-71.50036091999965 43.65595011300047)
# ...                                                ...
# 250932    POINT (-80.71264013499967 38.66551020200046)
# 250933    POINT (-97.52107021399968 35.47203135600046)
# 250934    POINT (-71.50036091999965 43.65595011300047)
# 250935    POINT (-78.45789046299967 37.54268067400045)
# 250936  POINT (-111.58713063499971 39.360700171000474)
#
# [250937 rows x 16 columns]

# %% [markdown]
# Ethnicity

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Creating label encoder
label_encoder = LabelEncoder()

# Handling NaN: temporarily fill NaN with a placeholder
placeholder = 'Missing'  # Use a unique placeholder not present in the actual data
df['Ethnicity'].fillna(placeholder, inplace=True)

# Fitting the encoder to the data (including the placeholder for NaN)
df['Ethnicity'] = label_encoder.fit_transform(df['Ethnicity'])

# Replace placeholder index back to NaN in the encoded data
placeholder_index = label_encoder.transform([placeholder])[0]
df['Ethnicity'] = df['Ethnicity'].replace(placeholder_index, pd.NA)

# Restoring NaN in the original column if desired
df['Ethnicity'].replace(placeholder, pd.NA, inplace=True)

# Output the original and encoded data
#print(df)

# Print the mapping from categories to integers
print("\nCategory to Integer Mapping:")
for i, category in enumerate(label_encoder.classes_):
    print(f"{category}: {i}")
# Out:
# Category to Integer Mapping:
# Asian/Pacific Islander: 0
# Black, non-Hispanic: 1
# Hispanic: 2
# Missing: 3
# Native Am/Alaskan Native: 4
# White, non-Hispanic: 5

# %%
# Print the mapping from categories to integers
print("\nCategory to Integer Mapping:")
for i, category in enumerate(label_encoder.classes_):
    print(f"{category}: {i}")
# Out:
# Category to Integer Mapping:
# Asian/Pacific Islander: 0
# Black, non-Hispanic: 1
# Hispanic: 2
# Missing: 3
# Native Am/Alaskan Native: 4
# White, non-Hispanic: 5

# %% [markdown]
# Class

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd


# Creating label encoder
label_encoder = LabelEncoder()

# Fitting the encoder to the data
df['Color_Encoded'] = label_encoder.fit_transform(df['Class'])

# Output the original and encoded data
print(df)
# Out:
#           RowId  YearStart  YearEnd LocationAbbr  \
# 0            A1       2021     2021         WEST
# 1            A2       2017     2017          NRE
# 2            A3       2019     2019          MDW
# 3            A4       2020     2020           US
# 4            A5       2020     2020           NH
# ...         ...        ...      ...          ...
# 250932  A250933       2015     2015           WV
# 250933  A250934       2015     2015           OK
# 250934  A250935       2017     2017           NH
# 250935  A250936       2015     2015           VA
# 250936  A250937       2015     2015           UT
#
#                            LocationDesc                                Class  \
# 0                                  West                       Overall Health
# 1                             Northeast                       Overall Health
# 2                               Midwest  Nutrition/Physical Activity/Obesity
# 3       United States, DC & Territories                       Overall Health
# 4                         New Hampshire                        Mental Health
# ...                                 ...                                  ...
# 250932                    West Virginia                    Cognitive Decline
# 250933                         Oklahoma                       Overall Health
# 250934                    New Hampshire                       Overall Health
# 250935                         Virginia                           Caregiving
# 250936                             Utah  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  \
# 0       Percentage of older adults ever told they have...
# 1       Percentage of older adults ever told they have...
# 2       Percentage of older adults who are eating 3 or...
# 3       Percentage of older adults ever told they have...
# 4       Percentage of older adults who are experiencin...
# ...                                                   ...
# 250932  Percentage of older adults who reported subjec...
# 250933  Mean number of days with activity limitations ...
# 250934  Severe joint pain due to arthritis among older...
# 250935  Average of 20 or more hours of care per week p...
# 250936  Percentage of older adults who are eating 3 or...
#
#        Low_Confidence_Limit High_Confidence_Limit Data_Value_Type  Data_Value  \
# 0                      28.8                  34.4      Percentage        31.6
# 1                      49.1                  51.6      Percentage        50.3
# 2                      13.8                  14.8      Percentage        14.3
# 3                      54.5                  56.4      Percentage        55.5
# 4                      12.8                    18      Percentage        15.2
# ...                     ...                   ...             ...         ...
# 250932                  NaN                   NaN      Percentage         NaN
# 250933                  4.7                   9.6            Mean         7.1
# 250934                 19.5                  24.5      Percentage        21.9
# 250935                  NaN                   NaN      Percentage         NaN
# 250936                 20.1                  39.6      Percentage        28.9
#
#          Age  Gender Ethnicity  \
# 0       <NA>     NaN         2
# 1          1     NaN      <NA>
# 2       <NA>     NaN      <NA>
# 3          1  Female      <NA>
# 4          0  Female      <NA>
# ...      ...     ...       ...
# 250932  <NA>     NaN         0
# 250933     0     NaN         1
# 250934  <NA>     NaN      <NA>
# 250935     1     NaN         2
# 250936     0     NaN         2
#
#                                            Geolocation  Color_Encoded
# 0                                                  NaN              4
# 1                                                  NaN              4
# 2                                                  NaN              3
# 3                                                  NaN              4
# 4         POINT (-71.50036091999965 43.65595011300047)              2
# ...                                                ...            ...
# 250932    POINT (-80.71264013499967 38.66551020200046)              1
# 250933    POINT (-97.52107021399968 35.47203135600046)              4
# 250934    POINT (-71.50036091999965 43.65595011300047)              4
# 250935    POINT (-78.45789046299967 37.54268067400045)              0
# 250936  POINT (-111.58713063499971 39.360700171000474)              3
#
# [250937 rows x 17 columns]

# %%
# Print the mapping from categories to integers
print("\nCategory to Integer Mapping:")
for i, category in enumerate(label_encoder.classes_):
    print(f"{category}: {i}")
# Out:
# Category to Integer Mapping:
# Caregiving: 0
# Cognitive Decline: 1
# Mental Health: 2
# Nutrition/Physical Activity/Obesity: 3
# Overall Health: 4
# Screenings and Vaccines: 5
# Smoking and Alcohol Use: 6

# %%
# Calculate the number of NaN values in each column
nan_count_per_column = df.isna().sum()
nan_count_per_column
# Out:
# RowId                         0
# YearStart                     0
# YearEnd                       0
# LocationAbbr                  0
# LocationDesc                  0
# Class                         0
# Topic                         0
# Question                      0
# Low_Confidence_Limit      81785
# High_Confidence_Limit     81785
# Data_Value_Type               0
# Data_Value                81635
# Age                       84147
# Gender                   190385
# Ethnicity                 92928
# Geolocation               26709
# Color_Encoded                 0
# dtype: int64

# %%
# Convert 'RowId' from A1, A2, ... to 1, 2, ..., 10
df['RowId'] = df['RowId'].apply(lambda x: int(x[1:]))  # Assuming all IDs are in the form 'A<number>'

print("\nDataFrame with Numeric Row IDs:")
# Out:
# DataFrame with Numeric Row IDs:
#          RowId  YearStart  YearEnd LocationAbbr  \
# 0            1       2021     2021         WEST
# 1            2       2017     2017          NRE
# 2            3       2019     2019          MDW
# 3            4       2020     2020           US
# 4            5       2020     2020           NH
# ...        ...        ...      ...          ...
# 250932  250933       2015     2015           WV
# 250933  250934       2015     2015           OK
# 250934  250935       2017     2017           NH
# 250935  250936       2015     2015           VA
# 250936  250937       2015     2015           UT
#
#                            LocationDesc                                Class  \
# 0                                  West                       Overall Health
# 1                             Northeast                       Overall Health
# 2                               Midwest  Nutrition/Physical Activity/Obesity
# 3       United States, DC & Territories                       Overall Health
# 4                         New Hampshire                        Mental Health
# ...                                 ...                                  ...
# 250932                    West Virginia                    Cognitive Decline
# 250933                         Oklahoma                       Overall Health
# 250934                    New Hampshire                       Overall Health
# 250935                         Virginia                           Caregiving
# 250936                             Utah  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  \
# 0       Percentage of older adults ever told they have...
# 1       Percentage of older adults ever told they have...
# 2       Percentage of older adults who are eating 3 or...
# 3       Percentage of older adults ever told they have...
# 4       Percentage of older adults who are experiencin...
# ...                                                   ...
# 250932  Percentage of older adults who reported subjec...
# 250933  Mean number of days with activity limitations ...
# 250934  Severe joint pain due to arthritis among older...
# 250935  Average of 20 or more hours of care per week p...
# 250936  Percentage of older adults who are eating 3 or...
#
#        Low_Confidence_Limit High_Confidence_Limit Data_Value_Type  Data_Value  \
# 0                      28.8                  34.4      Percentage        31.6
# 1                      49.1                  51.6      Percentage        50.3
# 2                      13.8                  14.8      Percentage        14.3
# 3                      54.5                  56.4      Percentage        55.5
# 4                      12.8                    18      Percentage        15.2
# ...                     ...                   ...             ...         ...
# 250932                  NaN                   NaN      Percentage         NaN
# 250933                  4.7                   9.6            Mean         7.1
# 250934                 19.5                  24.5      Percentage        21.9
# 250935                  NaN                   NaN      Percentage         NaN
# 250936                 20.1                  39.6      Percentage        28.9
#
#          Age  Gender Ethnicity  \
# 0       <NA>     NaN         2
# 1          1     NaN      <NA>
# 2       <NA>     NaN      <NA>
# 3          1  Female      <NA>
# 4          0  Female      <NA>
# ...      ...     ...       ...
# 250932  <NA>     NaN         0
# 250933     0     NaN         1
# 250934  <NA>     NaN      <NA>
# 250935     1     NaN         2
# 250936     0     NaN         2
#
#                                            Geolocation  Color_Encoded
# 0                                                  NaN              4
# 1                                                  NaN              4
# 2                                                  NaN              3
# 3                                                  NaN              4
# 4         POINT (-71.50036091999965 43.65595011300047)              2
# ...                                                ...            ...
# 250932    POINT (-80.71264013499967 38.66551020200046)              1
# 250933    POINT (-97.52107021399968 35.47203135600046)              4
# 250934    POINT (-71.50036091999965 43.65595011300047)              4
# 250935    POINT (-78.45789046299967 37.54268067400045)              0
# 250936  POINT (-111.58713063499971 39.360700171000474)              3
#
# [250937 rows x 17 columns]

# %%
df
# Out:
#          RowId  YearStart  YearEnd LocationAbbr  \
# 0            1       2021     2021         WEST
# 1            2       2017     2017          NRE
# 2            3       2019     2019          MDW
# 3            4       2020     2020           US
# 4            5       2020     2020           NH
# ...        ...        ...      ...          ...
# 250932  250933       2015     2015           WV
# 250933  250934       2015     2015           OK
# 250934  250935       2017     2017           NH
# 250935  250936       2015     2015           VA
# 250936  250937       2015     2015           UT
#
#                            LocationDesc                                Class  \
# 0                                  West                       Overall Health
# 1                             Northeast                       Overall Health
# 2                               Midwest  Nutrition/Physical Activity/Obesity
# 3       United States, DC & Territories                       Overall Health
# 4                         New Hampshire                        Mental Health
# ...                                 ...                                  ...
# 250932                    West Virginia                    Cognitive Decline
# 250933                         Oklahoma                       Overall Health
# 250934                    New Hampshire                       Overall Health
# 250935                         Virginia                           Caregiving
# 250936                             Utah  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  \
# 0       Percentage of older adults ever told they have...
# 1       Percentage of older adults ever told they have...
# 2       Percentage of older adults who are eating 3 or...
# 3       Percentage of older adults ever told they have...
# 4       Percentage of older adults who are experiencin...
# ...                                                   ...
# 250932  Percentage of older adults who reported subjec...
# 250933  Mean number of days with activity limitations ...
# 250934  Severe joint pain due to arthritis among older...
# 250935  Average of 20 or more hours of care per week p...
# 250936  Percentage of older adults who are eating 3 or...
#
#        Low_Confidence_Limit High_Confidence_Limit Data_Value_Type  Data_Value  \
# 0                      28.8                  34.4      Percentage        31.6
# 1                      49.1                  51.6      Percentage        50.3
# 2                      13.8                  14.8      Percentage        14.3
# 3                      54.5                  56.4      Percentage        55.5
# 4                      12.8                    18      Percentage        15.2
# ...                     ...                   ...             ...         ...
# 250932                  NaN                   NaN      Percentage         NaN
# 250933                  4.7                   9.6            Mean         7.1
# 250934                 19.5                  24.5      Percentage        21.9
# 250935                  NaN                   NaN      Percentage         NaN
# 250936                 20.1                  39.6      Percentage        28.9
#
#          Age  Gender Ethnicity  \
# 0       <NA>     NaN         2
# 1          1     NaN      <NA>
# 2       <NA>     NaN      <NA>
# 3          1  Female      <NA>
# 4          0  Female      <NA>
# ...      ...     ...       ...
# 250932  <NA>     NaN         0
# 250933     0     NaN         1
# 250934  <NA>     NaN      <NA>
# 250935     1     NaN         2
# 250936     0     NaN         2
#
#                                            Geolocation  Color_Encoded
# 0                                                  NaN              4
# 1                                                  NaN              4
# 2                                                  NaN              3
# 3                                                  NaN              4
# 4         POINT (-71.50036091999965 43.65595011300047)              2
# ...                                                ...            ...
# 250932    POINT (-80.71264013499967 38.66551020200046)              1
# 250933    POINT (-97.52107021399968 35.47203135600046)              4
# 250934    POINT (-71.50036091999965 43.65595011300047)              4
# 250935    POINT (-78.45789046299967 37.54268067400045)              0
# 250936  POINT (-111.58713063499971 39.360700171000474)              3
#
# [250937 rows x 17 columns]
